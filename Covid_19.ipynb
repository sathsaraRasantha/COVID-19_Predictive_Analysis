# %% [markdown]
# <a href="https://colab.research.google.com/github/sathsaraRasantha/COVID-19_Predictive_Analysis/blob/main/Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd

data=requests.get('https://www.hpb.health.gov.lk/api/get-current-statistical')
d=data.text
new=json.loads(d)

data1=[]
for i in range(0,35):
  data2=new['data']['hospital_data'][i]
  data1.append(data2)

data1
   


df = pd.json_normalize(data1)
df
# Out:
#     id  hospital_id  ...  hospital.updated_at  hospital.deleted_at
# 0    1            1  ...  2020-04-11 08:45:06                 None
# 1    2            2  ...  2020-04-11 08:45:06                 None
# 2    3            3  ...  2020-04-11 08:45:06                 None
# 3    4            4  ...  2020-04-11 08:45:06                 None
# 4    5            5  ...  2020-04-11 08:45:06                 None
# 5    6            6  ...  2020-04-11 08:45:06                 None
# 6    7            7  ...  2020-04-11 08:45:06                 None
# 7    8            8  ...  2020-04-11 08:45:06                 None
# 8    9            9  ...  2020-04-11 08:45:06                 None
# 9   10           10  ...  2020-04-11 08:45:06                 None
# 10  11           11  ...  2020-04-11 08:45:06                 None
# 11  12           12  ...  2020-04-11 08:45:06                 None
# 12  13           13  ...  2020-04-11 08:45:06                 None
# 13  14           14  ...  2020-04-11 08:45:06                 None
# 14  15           15  ...  2020-04-11 08:45:06                 None
# 15  16           16  ...  2020-04-11 08:45:06                 None
# 16  17           17  ...  2020-04-11 08:45:06                 None
# 17  18           18  ...  2020-04-11 08:45:06                 None
# 18  19           19  ...  2020-04-11 08:45:06                 None
# 19  20           20  ...  2020-04-11 08:45:06                 None
# 20  21           21  ...  2020-04-11 08:45:06                 None
# 21  22           22  ...  2020-04-11 08:45:06                 None
# 22  23           23  ...  2020-04-11 08:45:06                 None
# 23  24           24  ...  2020-04-11 08:45:06                 None
# 24  25           25  ...  2020-04-11 08:45:06                 None
# 25  26           26  ...  2020-04-11 08:45:06                 None
# 26  27           27  ...  2020-04-11 08:45:06                 None
# 27  28           28  ...  2020-04-11 08:45:06                 None
# 28  29           29  ...  2020-04-11 08:45:06                 None
# 29  30           30  ...  2020-04-11 08:45:06                 None
# 30  31           31  ...  2020-04-11 08:45:06                 None
# 31  32           32  ...  2020-04-11 08:45:06                 None
# 32  33           33  ...  2020-04-11 08:45:06                 None
# 33  34           34  ...  2020-04-30 00:00:00                 None
# 34  35           35  ...  2020-04-30 00:00:00                 None
#
# [35 rows x 18 columns]

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
df.to_csv('data.csv')
# !cp data.csv "drive/My Drive/"

# %%
len(new['data']['daily_pcr_testing_data'])

pcr=[]
for j in range(0,254):
  data3=new['data']['daily_pcr_testing_data'][j]
  pcr.append(data3)

df2 = pd.json_normalize(pcr)
df2
# Out:
#            date  count
# 0    2020-02-18      1
# 1    2020-02-19      0
# 2    2020-02-20      1
# 3    2020-02-21      0
# 4    2020-02-22      0
# ..          ...    ...
# 249  2020-10-24   9189
# 250  2020-10-25   8846
# 251  2020-10-26   9619
# 252  2020-10-27   8831
# 253  2020-10-28  11552
#
# [254 rows x 2 columns]

# %%
from google.colab import drive
drive.mount('drive')

df2.to_csv('data2.csv')
# !cp data2.csv "drive/My Drive/"
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%

#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 1,
#     'name': 'National Institute of Infectious Diseases',
#     'name_si': 'බෝවන රෝග පිළිබඳ ජාතික ආයතනය',
#     'name_ta': 'தேசிய தொற்று நோயியல் நிறுவனம்',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 1,
#    'id': 1,
#    'treatment_foreign': 0,
#    'treatment_local': 15,
#    'treatment_total': 15,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 16,
#    'cumulative_local': 1440,
#    'cumulative_total': 1456,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 2,
#     'name': 'National Hospital Sri Lanka',
#     'name_si': 'ශ්\u200dරී ලංකා ජාතික රෝහල',
#     'name_ta': 'இலங்கை தேசிய வைத்தியசாலை',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 2,
#    'id': 2,
#    'treatment_foreign': 0,
#    'treatment_local': 42,
#    'treatment_total': 42,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 5,
#    'cumulative_local': 1572,
#    'cumulative_total': 1577,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 3,
#     'name': 'TH - Ragama',
#     'name_si': 'ශික්ෂණ රෝහල - රාගම',
#     'name_ta': 'போதனா வைத்தியசாலை - ராகம',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 3,
#    'id': 3,
#    'treatment_foreign': 0,
#    'treatment_local': 32,
#    'treatment_total': 32,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 26,
#    'cumulative_local': 510,
#    'cumulative_total': 536,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 4,
#     'name': 'TH - Karapitiya',
#     'name_si': 'ශික්ෂණ රෝහල - කරපිටිය',
#     'name_ta': 'போதனா வைத்தியசாலை - கராபிடிய',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 4,
#    'id': 4,
#    'treatment_foreign': 0,
#    'treatment_local': 8,
#    'treatment_total': 8,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 2,
#    'cumulative_local': 1349,
#    'cumulative_total': 1351,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 5,
#     'name': 'TH - Anuradhapura',
#     'name_si': 'ශික්ෂණ රෝහල - අනුරාධපුර',
#     'name_ta': 'போதனா வைத்தியசாலை - அனுராதபுரம்',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 5,
#    'id': 5,
#    'treatment_foreign': 0,
#    'treatment_local': 8,
#    'treatment_total': 8,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 1,
#    'cumulative_local': 872,
#    'cumulative_total': 873,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 6,
#     'name': 'TH - Kurunegala',
#     'name_si': 'ශික්ෂණ රෝහල - කුරුණගල',
#     'name_ta': 'போதனா வைத்தியசாலை - குருநாகல்',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 6,
#    'id': 6,
#    'treatment_foreign': 0,
#    'treatment_local': 13,
#    'treatment_total': 13,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 2,
#    'cumulative_local': 197,
#    'cumulative_total': 199,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 7,
#     'name': 'TH- Jaffna',
#     'name_si': 'ශික්ෂණ රෝහල - යාපනය',
#     'name_ta': 'போதனா வைத்தியசாலை - யாழ்ப்பாணம்',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 7,
#    'id': 7,
#    'treatment_foreign': 0,
#    'treatment_local': 1,
#    'treatment_total': 1,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 6,
#    'cumulative_local': 245,
#    'cumulative_total': 251,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 8,
#     'name': 'National Hospital Kandy',
#     'name_si': 'ජාතික රෝහල - මහනුවර',
#     'name_ta': 'தேசிய வைத்தியசாலை கண்டி',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 8,
#    'id': 8,
#    'treatment_foreign': 0,
#    'treatment_local': 3,
#    'treatment_total': 3,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 282,
#    'cumulative_total': 282,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 9,
#     'name': 'TH – Batticaloa',
#     'name_si': 'ශික්ෂණ රෝහල - මඩකලපුව',
#     'name_ta': 'போதனா வைத்தியசாலை - மட்டக்களப்பு',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 9,
#    'id': 9,
#    'treatment_foreign': 0,
#    'treatment_local': 0,
#    'treatment_total': 0,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 4,
#    'cumulative_local': 498,
#    'cumulative_total': 502,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 10,
#     'name': 'DGH- Gampaha',
#     'name_si': 'දිස්ත්\u200dරික් මහ රෝහල - ගම්පහ',
#     'name_ta': 'மாவட்ட பொது வைத்தியசாலை - கம்பஹா',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 10,
#    'id': 10,
#    'treatment_foreign': 0,
#    'treatment_local': 10,
#    'treatment_total': 10,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 15,
#    'cumulative_local': 1366,
#    'cumulative_total': 1381,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 11,
#     'name': 'DGH – Negombo',
#     'name_si': 'දිස්ත්\u200dරික් මහ රෝහල - මීගමුව',
#     'name_ta': 'மாவட்ட பொது வைத்தியசாலை - நீர் கொழும்பு',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 11,
#    'id': 11,
#    'treatment_foreign': 0,
#    'treatment_local': 23,
#    'treatment_total': 23,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 425,
#    'cumulative_total': 425,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 12,
#     'name': 'TH – Rathnapura',
#     'name_si': 'ශික්ෂණ රෝහල - රත්නපුර',
#     'name_ta': 'போதனா வைத்தியசாலை - இரத்தினபுரி',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 12,
#    'id': 12,
#    'treatment_foreign': 0,
#    'treatment_local': 3,
#    'treatment_total': 3,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 2,
#    'cumulative_local': 129,
#    'cumulative_total': 131,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 13,
#     'name': 'PGH – Badulla',
#     'name_si': 'පළාත් මහ රෝහල - බදුල්ල',
#     'name_ta': 'மாகான அரச வைத்தியசாலை - பதுளை',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 13,
#    'id': 13,
#    'treatment_foreign': 0,
#    'treatment_local': 4,
#    'treatment_total': 4,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 150,
#    'cumulative_total': 150,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 14,
#     'name': 'LRH',
#     'name_si': 'රිජ්වේ ආර්යා ළමා රෝහල',
#     'name_ta': 'லேடி ரிட்ஜ்வே வைத்தியசாலை',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 14,
#    'id': 14,
#    'treatment_foreign': 0,
#    'treatment_local': 7,
#    'treatment_total': 7,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 1,
#    'cumulative_local': 392,
#    'cumulative_total': 393,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 15,
#     'name': 'DMH',
#     'name_si': 'ඩි සොයිසා කාන්තා රෝහල',
#     'name_ta': 'டி சோய்சா மகப்பேறு வைத்தியசாலை',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 15,
#    'id': 15,
#    'treatment_foreign': 0,
#    'treatment_local': 14,
#    'treatment_total': 14,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 6,
#    'cumulative_local': 614,
#    'cumulative_total': 620,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 16,
#     'name': 'DGH – Polonnaruwa',
#     'name_si': 'දිස්ත්\u200dරික් මහ රෝහල - පොලොන්නරුව',
#     'name_ta': 'மாவட்ட பொது வைத்தியசாலை - பொலன்னறுவை',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 16,
#    'id': 16,
#    'treatment_foreign': 0,
#    'treatment_local': 6,
#    'treatment_total': 6,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 5,
#    'cumulative_local': 493,
#    'cumulative_total': 498,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 17,
#     'name': 'TH - Kalubowila',
#     'name_si': 'දිස්ත්\u200dරික් මහ රෝහල - කලුබෝවිල',
#     'name_ta': 'கொழும்பு தெற்கு போதனா வைத்தியசாலை',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 17,
#    'id': 17,
#    'treatment_foreign': 0,
#    'treatment_local': 8,
#    'treatment_total': 8,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 414,
#    'cumulative_total': 414,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 18,
#     'name': 'Castle Street Teaching Hospital',
#     'name_si': 'කාසල් වීදියේ ශික්ෂණ රෝහල',
#     'name_ta': 'காசல் வீதி மகளிர் போதனா மருத்துவமனை',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 18,
#    'id': 18,
#    'treatment_foreign': 0,
#    'treatment_local': 11,
#    'treatment_total': 11,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 2,
#    'cumulative_local': 382,
#    'cumulative_total': 384,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 19,
#     'name': 'Base Hospital- Hambantota',
#     'name_si': 'මූලික රෝහල - හම්බන්තොට',
#     'name_ta': 'ஆதார வைத்தியசாலை- ஹம்பாந்தோட்டா',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 19,
#    'id': 19,
#    'treatment_foreign': 0,
#    'treatment_local': 1,
#    'treatment_total': 1,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 209,
#    'cumulative_total': 209,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 20,
#     'name': 'Base Hospital - Monaragala',
#     'name_si': 'මූලික රෝහල - මොනරාගල',
#     'name_ta': 'ஆதார வைத்தியசாலை- மோனராகலா',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 20,
#    'id': 20,
#    'treatment_foreign': 0,
#    'treatment_local': 4,
#    'treatment_total': 4,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 1,
#    'cumulative_local': 69,
#    'cumulative_total': 70,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 21,
#     'name': 'Base Hospital - Welikanda',
#     'name_si': 'මූලික රෝහල - වැලිකන්ද',
#     'name_ta': 'ஆதார வைத்தியசாலை- வாலிகண்ட',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 21,
#    'id': 21,
#    'treatment_foreign': 0,
#    'treatment_local': 0,
#    'treatment_total': 0,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 2,
#    'cumulative_local': 760,
#    'cumulative_total': 762,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 22,
#     'name': 'DGH-Kalutara',
#     'name_si': 'දිස්ත්\u200dරික් මහ රෝහල - කළුතර',
#     'name_ta': 'மாவட்ட பொது வைத்தியசாலை -களுத்துறை',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 22,
#    'id': 22,
#    'treatment_foreign': 0,
#    'treatment_local': 9,
#    'treatment_total': 9,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 2,
#    'cumulative_local': 544,
#    'cumulative_total': 546,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 23,
#     'name': 'Chest Hospital Welisara',
#     'name_si': 'ළය රෝහල - වැලිසර',
#     'name_ta': 'மார்பு வைத்தியசாலை -வெலிசரா',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 23,
#    'id': 23,
#    'treatment_foreign': 0,
#    'treatment_local': 7,
#    'treatment_total': 7,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 56,
#    'cumulative_total': 56,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 24,
#     'name': 'Base Hospital Mulleriyawa',
#     'name_si': 'මූලික රෝහල  - මුල්ලේරියාව',
#     'name_ta': 'ஆதார வைத்தியசாலை - முல்லேரியா',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 24,
#    'id': 24,
#    'treatment_foreign': 0,
#    'treatment_local': 0,
#    'treatment_total': 0,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 4,
#    'cumulative_local': 302,
#    'cumulative_total': 306,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 25,
#     'name': 'Base Hospital Homagama',
#     'name_si': 'මූලික රෝහල  - හෝමාගම',
#     'name_ta': 'ஆதார வைத்தியசாலை - ஹோமாகம',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 25,
#    'id': 25,
#    'treatment_foreign': 0,
#    'treatment_local': 0,
#    'treatment_total': 0,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 84,
#    'cumulative_total': 84,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 26,
#     'name': 'Dr. Nevil Fernando Hospital',
#     'name_si': 'නෙවිල් ප්\u200dරනාන්දු රෝහල',
#     'name_ta': 'வைத்தியர் நெவில் பெர்னாண்டோ வைத்தியசாலை',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 26,
#    'id': 26,
#    'treatment_foreign': 0,
#    'treatment_local': 0,
#    'treatment_total': 0,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 1,
#    'cumulative_local': 2876,
#    'cumulative_total': 2877,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 27,
#     'name': 'D. G.H. Chillaw',
#     'name_si': 'දිස්ත්\u200dරික් මහ රෝහල - හලාවත',
#     'name_ta': 'மாவட்ட பொது வைத்தியசாலை – சில்லாவ்',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 27,
#    'id': 27,
#    'treatment_foreign': 0,
#    'treatment_local': 7,
#    'treatment_total': 7,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 2,
#    'cumulative_local': 158,
#    'cumulative_total': 160,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 28,
#     'name': 'D.G.H. Matara',
#     'name_si': 'දිස්ත්\u200dරික් මහ රෝහල - මාතර',
#     'name_ta': 'மாவட்ட பொது வைத்தியசாலை - மாதாரா',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 28,
#    'id': 28,
#    'treatment_foreign': 0,
#    'treatment_local': 0,
#    'treatment_total': 0,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 1784,
#    'cumulative_total': 1784,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 29,
#     'name': 'K.D.U. Hospital',
#     'name_si': 'කොතලාවල ආරක්ෂක විශ්ව විද්\u200dයාල රෝහල',
#     'name_ta': 'கொத்தலாவெல பாதுகாப்பு பல்கலைக்கழக (k.D.U)  வைத்தியசாலை',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 29,
#    'id': 29,
#    'treatment_foreign': 0,
#    'treatment_local': 58,
#    'treatment_total': 58,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 190,
#    'cumulative_total': 190,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 30,
#     'name': 'D.G.H. Vavunia',
#     'name_si': 'දිස්ත්\u200dරික් මහ රෝහල - වවුනියාව',
#     'name_ta': 'மாவட்ட பொது வைத்தியசாலை - வவுனியா',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 30,
#    'id': 30,
#    'treatment_foreign': 0,
#    'treatment_local': 1,
#    'treatment_total': 1,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 1,
#    'cumulative_local': 226,
#    'cumulative_total': 227,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 31,
#     'name': 'Base Hospital - Marawila',
#     'name_si': 'මූලික රෝහල - මාරවිල',
#     'name_ta': 'தள வைத்தியசாலை – மாறவில',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 31,
#    'id': 31,
#    'treatment_foreign': 0,
#    'treatment_local': 6,
#    'treatment_total': 6,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 2,
#    'cumulative_local': 2931,
#    'cumulative_total': 2933,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 32,
#     'name': 'Teaching Hospital - Sri Jayawadhanapura',
#     'name_si': 'දශික්ෂණ රෝහල - ශ්\u200dරී ජයවර්ධනපුර',
#     'name_ta': 'போதனா வைத்தியசாலை- ஸ்ரீ ஜயவர்த்தனபுர',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 32,
#    'id': 32,
#    'treatment_foreign': 0,
#    'treatment_local': 91,
#    'treatment_total': 91,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 12,
#    'cumulative_total': 12,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-11 08:45:06',
#     'deleted_at': None,
#     'id': 33,
#     'name': 'Base Hospital - Beruwala',
#     'name_si': 'මූලික රෝහල - බේරුවල',
#     'name_ta': 'தள வைத்தியசாலை – பெருவாலா',
#     'updated_at': '2020-04-11 08:45:06'},
#    'hospital_id': 33,
#    'id': 33,
#    'treatment_foreign': 0,
#    'treatment_local': 0,
#    'treatment_total': 0,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 3,
#    'cumulative_total': 3,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-30 00:00:00',
#     'deleted_at': None,
#     'id': 34,
#     'name': 'Base Hospital – Kathankudi',
#     'name_si': 'මූලික රෝහල - කාතන්කුඩි',
#     'name_ta': 'தள வைத்தியசாலை – காத்தான்குடி',
#     'updated_at': '2020-04-30 00:00:00'},
#    'hospital_id': 34,
#    'id': 34,
#    'treatment_foreign': 0,
#    'treatment_local': 0,
#    'treatment_total': 0,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 6,
#    'cumulative_total': 6,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-30 00:00:00',
#     'deleted_at': None,
#     'id': 35,
#     'name': 'Base Hospital – Minuwangoda',
#     'name_si': 'මූලික රෝහල - මිනුවන්ගොඩ',
#     'name_ta': 'தள வைத்தியசாலை – மினுவாங்கோடா',
#     'updated_at': '2020-04-30 00:00:00'},
#    'hospital_id': 35,
#    'id': 35,
#    'treatment_foreign': 0,
#    'treatment_local': 0,
#    'treatment_total': 0,
#    'updated_at': None},
#   {'created_at': '2020-10-29 15:42:37',
#    'cumulative_foreign': 0,
#    'cumulative_local': 218,
#    'cumulative_total': 218,
#    'deleted_at': None,
#    'hospital': {'created_at': '2020-04-30 00:00:00',
#     'deleted_at': None,
#     'id': 36,
#     'name': 'Navy Hospital',
#     'name_si': 'නාවික හමුදා රෝහල',
#     'name_ta': 'கடற்படை வைத்தியசாலை',
#     'updated_at': '2020-04-30 00:00:00'},
#    'hospital_id': 36,
#    'id': 36,
#    'treatment_foreign': 0,
#    'treatment_local': 0,
#    'treatment_total': 0,
#    'updated_at': None}],
#  'local_active_cases': 5630,
#  'local_deaths': 19,
#  'local_new_cases': 0,
#  'local_new_deaths': 0,
#  'local_recovered': 4142,
#  'local_total_cases': 9791,
#  'local_total_number_of_individuals_in_hospitals': 435,
#  'total_pcr_testing_count': 490563,
#  'update_date_time': '2020-10-30 06:48:22'}

# %%
import requests
import json
import pandas as pd

world_data=requests.get('https://api.covid19api.com/country/sri-lanka')
world_data
world_data_to_text=world_data.text
world_data_json=json.loads(world_data_to_text)
len(world_data_json)
sl_data=[]
for i in range(0,281):
  data=world_data_json[i]
  sl_data.append(data)

sl_data
# Out:
# [{'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 0,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-01-22T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 0,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-01-23T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 0,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-01-24T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 0,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-01-25T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 0,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-01-26T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-01-27T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-01-28T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-01-29T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-01-30T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-01-31T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-01T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-02T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-03T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-04T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-05T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-06T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-07T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 0},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-08T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-09T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-10T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-11T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-12T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-13T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-14T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-15T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-16T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-17T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-18T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-19T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-20T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-21T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-22T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-23T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-24T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-25T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-26T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-27T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-28T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-02-29T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-01T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-02T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-03T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-04T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-05T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-06T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-07T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-08T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-09T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 0,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-10T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-11T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 1,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-12T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 5,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 6,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-13T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 9,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 10,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-14T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 17,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 18,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-15T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 27,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 28,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-16T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 43,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 44,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-17T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 50,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 51,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-18T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 57,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 60,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-19T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3},
#  {'Active': 70,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 73,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-20T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3},
#  {'Active': 76,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 77,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-21T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1},
#  {'Active': 79,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 82,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-22T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3},
#  {'Active': 94,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 97,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-23T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3},
#  {'Active': 100,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 102,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-24T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2},
#  {'Active': 99,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 102,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-25T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3},
#  {'Active': 99,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 106,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-26T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 7},
#  {'Active': 99,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 106,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-27T00:00:00Z',
#   'Deaths': 0,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 7},
#  {'Active': 103,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 113,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-28T00:00:00Z',
#   'Deaths': 1,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 9},
#  {'Active': 105,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 117,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-29T00:00:00Z',
#   'Deaths': 1,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 11},
#  {'Active': 105,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 122,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-30T00:00:00Z',
#   'Deaths': 2,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 15},
#  {'Active': 124,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 143,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-03-31T00:00:00Z',
#   'Deaths': 2,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 17},
#  {'Active': 122,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 146,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-01T00:00:00Z',
#   'Deaths': 3,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 21},
#  {'Active': 126,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 151,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-02T00:00:00Z',
#   'Deaths': 4,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 21},
#  {'Active': 131,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 159,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-03T00:00:00Z',
#   'Deaths': 4,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 24},
#  {'Active': 134,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 166,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-04T00:00:00Z',
#   'Deaths': 5,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 27},
#  {'Active': 138,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 176,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-05T00:00:00Z',
#   'Deaths': 5,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 33},
#  {'Active': 135,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 178,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-06T00:00:00Z',
#   'Deaths': 5,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 38},
#  {'Active': 137,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 185,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-07T00:00:00Z',
#   'Deaths': 6,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 42},
#  {'Active': 138,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 189,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-08T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 44},
#  {'Active': 134,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 190,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-09T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 49},
#  {'Active': 129,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 190,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-10T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 54},
#  {'Active': 137,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 198,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-11T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 54},
#  {'Active': 147,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 210,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-12T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 56},
#  {'Active': 154,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 217,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-13T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 56},
#  {'Active': 165,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 233,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-14T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 61},
#  {'Active': 168,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 238,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-15T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 63},
#  {'Active': 163,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 238,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-16T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 68},
#  {'Active': 160,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 244,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-17T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 77},
#  {'Active': 161,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 254,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-18T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 86},
#  {'Active': 168,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 271,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-19T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 96},
#  {'Active': 199,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 304,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-20T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 98},
#  {'Active': 201,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 310,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-21T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 102},
#  {'Active': 218,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 330,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-22T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 105},
#  {'Active': 254,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 368,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-23T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 107},
#  {'Active': 304,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 420,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-24T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 109},
#  {'Active': 335,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 460,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-25T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 118},
#  {'Active': 396,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 523,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-26T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 120},
#  {'Active': 455,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 588,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-27T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 126},
#  {'Active': 478,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 619,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-28T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 134},
#  {'Active': 506,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 649,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-29T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 136},
#  {'Active': 502,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 663,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-04-30T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 154},
#  {'Active': 521,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 690,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-01T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 162},
#  {'Active': 526,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 705,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-02T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 172},
#  {'Active': 527,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 718,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-03T00:00:00Z',
#   'Deaths': 7,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 184},
#  {'Active': 549,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 751,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-04T00:00:00Z',
#   'Deaths': 8,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 194},
#  {'Active': 549,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 771,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-05T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 213},
#  {'Active': 573,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 797,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-06T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 215},
#  {'Active': 583,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 824,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-07T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 232},
#  {'Active': 586,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 835,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-08T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 240},
#  {'Active': 578,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 847,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-09T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 260},
#  {'Active': 533,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 863,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-10T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 321},
#  {'Active': 517,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 869,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-11T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 343},
#  {'Active': 514,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 889,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-12T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 366},
#  {'Active': 524,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 915,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-13T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 382},
#  {'Active': 471,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 925,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-14T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 445},
#  {'Active': 449,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 935,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-15T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 477},
#  {'Active': 431,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 960,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-16T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 520},
#  {'Active': 434,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 981,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-17T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 538},
#  {'Active': 424,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 992,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-18T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 559},
#  {'Active': 449,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1027,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-19T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 569},
#  {'Active': 435,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1028,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-20T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 584},
#  {'Active': 442,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1055,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-21T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 604},
#  {'Active': 439,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1068,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-22T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 620},
#  {'Active': 420,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1089,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-23T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 660},
#  {'Active': 458,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1141,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-24T00:00:00Z',
#   'Deaths': 9,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 674},
#  {'Active': 477,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1182,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-25T00:00:00Z',
#   'Deaths': 10,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 695},
#  {'Active': 597,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1319,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-26T00:00:00Z',
#   'Deaths': 10,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 712},
#  {'Active': 727,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1469,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-27T00:00:00Z',
#   'Deaths': 10,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 732},
#  {'Active': 775,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1530,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-28T00:00:00Z',
#   'Deaths': 10,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 745},
#  {'Active': 794,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1558,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-29T00:00:00Z',
#   'Deaths': 10,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 754},
#  {'Active': 829,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1620,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-30T00:00:00Z',
#   'Deaths': 10,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 781},
#  {'Active': 822,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1633,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-05-31T00:00:00Z',
#   'Deaths': 10,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 801},
#  {'Active': 821,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1643,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-01T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 811},
#  {'Active': 849,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1683,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-02T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 823},
#  {'Active': 902,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1749,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-03T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 836},
#  {'Active': 947,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1797,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-04T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 839},
#  {'Active': 932,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1801,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-05T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 858},
#  {'Active': 912,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1814,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-06T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 891},
#  {'Active': 883,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1835,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-07T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 941},
#  {'Active': 856,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1857,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-08T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 990},
#  {'Active': 791,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1859,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-09T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1057},
#  {'Active': 736,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1869,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-10T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1122},
#  {'Active': 716,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1877,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-11T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1150},
#  {'Active': 673,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1880,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-12T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1196},
#  {'Active': 621,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1884,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-13T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1252},
#  {'Active': 591,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1889,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-14T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1287},
#  {'Active': 552,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1905,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-15T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1342},
#  {'Active': 533,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1915,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-16T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1371},
#  {'Active': 516,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1924,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-17T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1397},
#  {'Active': 515,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1947,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-18T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1421},
#  {'Active': 493,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1950,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-19T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1446},
#  {'Active': 467,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1950,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-20T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1472},
#  {'Active': 441,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1950,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-21T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1498},
#  {'Active': 414,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1951,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-22T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1526},
#  {'Active': 432,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 1991,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-23T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1548},
#  {'Active': 428,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2001,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-24T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1562},
#  {'Active': 397,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2010,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-25T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1602},
#  {'Active': 384,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2014,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-26T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1619},
#  {'Active': 383,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2033,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-27T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1639},
#  {'Active': 365,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2037,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-28T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1661},
#  {'Active': 350,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2039,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-29T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1678},
#  {'Active': 325,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2047,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-06-30T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1711},
#  {'Active': 295,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2054,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-01T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1748},
#  {'Active': 228,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2066,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-02T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1827},
#  {'Active': 195,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2069,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-03T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1863},
#  {'Active': 178,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2074,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-04T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1885},
#  {'Active': 162,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2076,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-05T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1903},
#  {'Active': 149,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2077,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-06T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1917},
#  {'Active': 115,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2081,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-07T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1955},
#  {'Active': 116,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2094,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-08T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1967},
#  {'Active': 164,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2154,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-09T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1979},
#  {'Active': 463,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2454,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-10T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1980},
#  {'Active': 520,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2511,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-11T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1980},
#  {'Active': 625,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2617,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-12T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1981},
#  {'Active': 654,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2646,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-13T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1981},
#  {'Active': 666,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2665,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-14T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 1988},
#  {'Active': 659,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2671,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-15T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2001},
#  {'Active': 669,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2687,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-16T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2007},
#  {'Active': 674,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2697,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-17T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2012},
#  {'Active': 669,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2703,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-18T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2023},
#  {'Active': 678,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2724,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-19T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2035},
#  {'Active': 678,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2730,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-20T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2041},
#  {'Active': 671,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2730,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-21T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2048},
#  {'Active': 677,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2752,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-22T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2064},
#  {'Active': 665,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2753,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-23T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2077},
#  {'Active': 659,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2764,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-24T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2094},
#  {'Active': 656,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2770,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-25T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2103},
#  {'Active': 665,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2782,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-26T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2106},
#  {'Active': 673,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2805,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-27T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2121},
#  {'Active': 503,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2810,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-28T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2296},
#  {'Active': 482,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2810,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-29T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2317},
#  {'Active': 470,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2814,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-30T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2333},
#  {'Active': 413,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2815,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-07-31T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2391},
#  {'Active': 365,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2815,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-01T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2439},
#  {'Active': 298,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2823,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-02T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2514},
#  {'Active': 300,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2828,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-03T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2517},
#  {'Active': 299,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2834,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-04T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2524},
#  {'Active': 291,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2839,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-05T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2537},
#  {'Active': 287,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2839,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-06T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2541},
#  {'Active': 264,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2839,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-07T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2564},
#  {'Active': 254,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2841,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-08T00:00:00Z',
#   'Deaths': 11,
#   'Lat': '7.87',
#   'Lon': '80.77',
# ...
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2811},
#  {'Active': 143,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2971,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-25T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2816},
#  {'Active': 153,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2984,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-26T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2819},
#  {'Active': 144,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2986,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-27T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2830},
#  {'Active': 135,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2989,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-28T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2842},
#  {'Active': 134,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 2995,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-29T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2849},
#  {'Active': 140,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3012,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-30T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2860},
#  {'Active': 169,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3049,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-08-31T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2868},
#  {'Active': 201,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3092,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-01T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2879},
#  {'Active': 206,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3101,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-02T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2883},
#  {'Active': 216,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3111,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-03T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2883},
#  {'Active': 196,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3115,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-04T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2907},
#  {'Active': 191,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3121,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-05T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2918},
#  {'Active': 186,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3123,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-06T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2925},
#  {'Active': 185,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3123,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-07T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2926},
#  {'Active': 193,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3140,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-08T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2935},
#  {'Active': 189,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3147,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-09T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2946},
#  {'Active': 188,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3155,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-10T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2955},
#  {'Active': 188,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3169,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-11T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2969},
#  {'Active': 200,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3195,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-12T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2983},
#  {'Active': 226,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3234,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-13T00:00:00Z',
#   'Deaths': 12,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 2996},
#  {'Active': 244,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3262,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-14T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3005},
#  {'Active': 242,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3271,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-15T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3016},
#  {'Active': 237,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3271,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-16T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3021},
#  {'Active': 220,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3276,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-17T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3043},
#  {'Active': 208,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3281,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-18T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3060},
#  {'Active': 200,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3283,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-19T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3070},
#  {'Active': 186,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3287,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-20T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3088},
#  {'Active': 186,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3299,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-21T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3100},
#  {'Active': 182,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3313,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-22T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3118},
#  {'Active': 182,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3324,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-23T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3129},
#  {'Active': 178,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3333,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-24T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3142},
#  {'Active': 174,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3345,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-25T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3158},
#  {'Active': 150,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3349,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-26T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3186},
#  {'Active': 139,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3360,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-27T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3208},
#  {'Active': 140,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3363,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-28T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3210},
#  {'Active': 131,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3374,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-29T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3230},
#  {'Active': 137,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3380,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-09-30T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3230},
#  {'Active': 136,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3382,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-01T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3233},
#  {'Active': 130,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3388,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-02T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3245},
#  {'Active': 128,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3395,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-03T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3254},
#  {'Active': 131,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3402,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-04T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3258},
#  {'Active': 241,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 3513,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-05T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3259},
#  {'Active': 973,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 4252,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-06T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3266},
#  {'Active': 1172,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 4459,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-07T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3274},
#  {'Active': 1197,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 4488,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-08T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3278},
#  {'Active': 1214,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 4523,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-09T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3296},
#  {'Active': 1309,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 4628,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-10T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3306},
#  {'Active': 1432,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 4752,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-11T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3307},
#  {'Active': 1514,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 4844,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-12T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3317},
#  {'Active': 1697,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 5038,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-13T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3328},
#  {'Active': 1800,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 5170,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-14T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3357},
#  {'Active': 1851,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 5244,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-15T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3380},
#  {'Active': 1956,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 5354,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-16T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3385},
#  {'Active': 2067,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 5475,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-17T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3395},
#  {'Active': 2122,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 5538,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-18T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3403},
#  {'Active': 2172,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 5625,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-19T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3440},
#  {'Active': 2341,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 5811,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-20T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3457},
#  {'Active': 2464,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 5978,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-21T00:00:00Z',
#   'Deaths': 13,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3501},
#  {'Active': 2712,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 6287,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-22T00:00:00Z',
#   'Deaths': 14,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3561},
#  {'Active': 3495,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 7153,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-23T00:00:00Z',
#   'Deaths': 14,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3644},
#  {'Active': 3792,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 7521,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-24T00:00:00Z',
#   'Deaths': 15,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3714},
#  {'Active': 4053,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 7872,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-25T00:00:00Z',
#   'Deaths': 16,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3803},
#  {'Active': 4464,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 8413,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-26T00:00:00Z',
#   'Deaths': 16,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 3933},
#  {'Active': 4808,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 8870,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-27T00:00:00Z',
#   'Deaths': 19,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 4043},
#  {'Active': 5111,
#   'City': '',
#   'CityCode': '',
#   'Confirmed': 9205,
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Date': '2020-10-28T00:00:00Z',
#   'Deaths': 19,
#   'Lat': '7.87',
#   'Lon': '80.77',
#   'Province': '',
#   'Recovered': 4075}]

# %%
sl_df = pd.json_normalize(sl_data)
sl_df
# Out:
#        Country CountryCode Province  ... Recovered Active                  Date
# 0    Sri Lanka          LK           ...         0      0  2020-01-22T00:00:00Z
# 1    Sri Lanka          LK           ...         0      0  2020-01-23T00:00:00Z
# 2    Sri Lanka          LK           ...         0      0  2020-01-24T00:00:00Z
# 3    Sri Lanka          LK           ...         0      0  2020-01-25T00:00:00Z
# 4    Sri Lanka          LK           ...         0      0  2020-01-26T00:00:00Z
# ..         ...         ...      ...  ...       ...    ...                   ...
# 276  Sri Lanka          LK           ...      3714   3792  2020-10-24T00:00:00Z
# 277  Sri Lanka          LK           ...      3803   4053  2020-10-25T00:00:00Z
# 278  Sri Lanka          LK           ...      3933   4464  2020-10-26T00:00:00Z
# 279  Sri Lanka          LK           ...      4043   4808  2020-10-27T00:00:00Z
# 280  Sri Lanka          LK           ...      4075   5111  2020-10-28T00:00:00Z
#
# [281 rows x 12 columns]

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
sl_df.to_csv('COVID_Time_srs.csv')
# !cp COVID_Time_srs.csv "drive/My Drive/"

# %%
import matplotlib.pyplot as plt
import datetime

fig, ax = plt.subplots(figsize = (12,6))    
fig = sns.lineplot(x = "Date", y = "Confirmed", data =sl_df)
#sl_df['Date']=pd.to_datetime(sl_df['Date'])
#x_dates = sl_df['Date'].dt.strftime('%d')
#ax.set_xticklabels(labels=sl_df['Date'], rotation=90, ha='right')

# %%
fig, ax = plt.subplots(figsize = (12,6))    
fig = sns.lineplot(x = "Date", y = "Recovered", data =sl_df)

# %%
ax = plt.gca()

sl_df.plot(kind='line',x='Date',y='Recovered',ax=ax)
sl_df.plot(kind='line',x='Date',y='Confirmed', color='red', ax=ax)

plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-528a4843-0dec-4397-a256-25e475cff4fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-528a4843-0dec-4397-a256-25e475cff4fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving COVIDSL.COM Data.csv to COVIDSL.COM Data.csv

# %%
import pandas as pd
district_data=pd.read_csv("COVIDSL.COM Data.csv")
district_data
# Out:
#              Date Announced  ... City Patient Number  Charter Flight Passenger
# 0        1.0     2020-01-27  ...                 NaN                       NaN
# 1        2.0     2020-03-10  ...                 NaN                       NaN
# 2        3.0     2020-03-12  ...                 NaN                       NaN
# 3        4.0     2020-03-13  ...                 NaN                       NaN
# 4        5.0     2020-03-13  ...                 NaN                       NaN
# ...      ...            ...  ...                 ...                       ...
# 9788  9787.0     2020-10-29  ...                 NaN                       NaN
# 9789  9788.0     2020-10-29  ...                 NaN                       NaN
# 9790  9789.0     2020-10-29  ...                 NaN                       NaN
# 9791  9790.0     2020-10-29  ...                 NaN                       NaN
# 9792  9791.0     2020-10-29  ...                 NaN                       NaN
#
# [9793 rows x 18 columns]

# %%
district_data_filtered=district_data.drop(['Click Here For Sheet Information','Status','Notes','Source(s)','Related Patients','Prefecture Patient Number',	'Charter Flight Passenger'],axis=1)
district_data_filtered['Detected City'].unique()
# Out:
# array(['Katunayake', 'Colombo', 'Gampaha', 'Kurunegala', 'Puttalam',
#        'Galle', 'Polonnaruwa', 'Batticaloa', 'Kandy', 'Ratnapura',
#        'Vavuniya', 'Kegalle', 'Kalutara', 'Badulla', 'Jaffna', 'Matara',
#        'Unspecified', ' Kurunegala', 'Ampara', ' Ja-ela', ' Jaffna',
#        ' Ja-Ela', ' Al-Casim city', ' Thotalaga', ' Beruwala',
#        ' Wariyapola', 'Naval Base - Welisara ', ' Ratnapua',
#        ' Polgahawela', ' Girandurukotte', 'Anuradhapura', 'Trincomalee',
#        ' Kuliyapitiya', ' Kambagamuwa', ' Divulgahamula', 'Pahalaborgama',
#        ' 13 1/2th Mile post', ' Pelenwatta', 'Moneragala',
#        ' Nawalapitiya', ' Suriyawewa', ' Tangalle', ' Narahenpita',
#        ' Saliyapura', ' Torinton ', ' Uhana', ' Kanthale', 'Nuwara Eliya',
#        ' Methsanda Niwasa', ' Rajagiriya', ' Kolonnawa', ' Giribawa',
#        ' Colombo', 'Overseas Arrivals (Quarantine Centers)',
#        'Kandakadu Rehabilitation Center', 'Matale', ' Heenatigla',
#        ' Pattiyapola', ' Kithulhitiyawa', ' Habareththa', ' Thalpatha',
#        '3', 'Senapura Rehabilitation Center', ' Dalthara', 'Kendalanda',
#        'Godagama', ' Aguruwana', ' Werellawatta', ' Diyawiddagama', nan,
#        ' Galahitiyawa', ' Nakkawatta', ' Bakingahawela', ' Pallepola',
#        ' Wetakeiyyawa', ' Iddapola', ' Wilgamuwa', ' Kandahena',
#        ' Uyandana', ' Rwaela', ' Kandanhena', ' Barigoda', ' Wijerama',
#        'Mannar', ' Eluwapitiya', ' Slav Island', 'Hambantota'],
#       dtype=object)

# %%
district_data_filtered['Detected City'].unique()

colombo_cities=['Colombo',' Torinton ',' Rajagiriya',' Kolonnawa',' Colombo','Godagama',' Wijerama',' Slav Island',' Pelenwatta',' Narahenpita',' Dalthara']
gampaha_cities=['Katunayake','Gampaha',' Ja-ela',' Ja-Ela',' Divulgahamula','Kendalanda',' Werellawatta',' Nakkawatta',' Thotalaga',' Nawalapitiya',' Eluwapitiya']
kalutara_cities=['Kalutara',' Al-Casim city',' Beruwala',' Kandanhena',]
kurunegala_cities=[' Kurunegala',' Wariyapola',' Polgahawela',' Kuliyapitiya',' Kambagamuwa',' Divulgahamula',' Giribawa',' Wetakeiyyawa',' Uyandana']
qurantine_centers=['Naval Base - Welisara ','Overseas Arrivals (Quarantine Centers)','Kandakadu Rehabilitation Center','Senapura Rehabilitation Center']
other=[ 'Puttalam','Galle', 'Polonnaruwa', 'Batticaloa', 'Kandy', 'Ratnapura','Vavuniya', 'Kegalle',  'Badulla', 'Jaffna', 'Matara','Unspecified', 'Ampara',  ' Jaffna',
       ' Ratnapua',' Girandurukotte', 'Anuradhapura', 'Trincomalee', 'Pahalaborgama', ' 13 1/2th Mile post',  'Moneragala', ' Suriyawewa', ' Tangalle',  ' Saliyapura',  ' Uhana',
       ' Kanthale', 'Nuwara Eliya',' Methsanda Niwasa',' Habareththa', ' Thalpatha',   '3',  ' Dalthara', ' Aguruwana', ' Werellawatta', ' Diyawiddagama',  ' Galahitiyawa',
       ' Nakkawatta', ' Bakingahawela', ' Pallepola', ' Wetakeiyyawa', ' Iddapola', ' Wilgamuwa',   ' Rwaela',  ' Barigoda',   'Mannar',  'Hambantota']

for i in range(0,9792):
  for item in colombo_cities:
    if district_data_filtered['Detected City'][i]==item:
      district_data_filtered['City Patient Number'][i]="Colombo"

for i in range(0,9792):
  for item in gampaha_cities:
    if district_data_filtered['Detected City'][i]==item:
      district_data_filtered['City Patient Number'][i]="Gampaha"

for i in range(0,9792):
  for item in kalutara_cities:
    if district_data_filtered['Detected City'][i]==item:
      district_data_filtered['City Patient Number'][i]="Kalutara"

for i in range(0,9792):
  for item in kurunegala_cities:
    if district_data_filtered['Detected City'][i]==item:
      district_data_filtered['City Patient Number'][i]="Kurunegala"

for i in range(0,9792):
  for item in qurantine_centers:
    if district_data_filtered['Detected City'][i]==item:
      district_data_filtered['City Patient Number'][i]="Qurantine Centers"

for i in range(0,9792):
  for item in other:
    if district_data_filtered['Detected City'][i]==item:
      district_data_filtered['City Patient Number'][i]="other"
    



district_data_filtered
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              Date Announced  ... Known Cluster  City Patient Number
# 0        1.0     2020-01-27  ...           NaN              Gampaha
# 1        2.0     2020-03-10  ...           NaN              Colombo
# 2        3.0     2020-03-12  ...           NaN              Colombo
# 3        4.0     2020-03-13  ...           NaN              Colombo
# 4        5.0     2020-03-13  ...           NaN              Gampaha
# ...      ...            ...  ...           ...                  ...
# 9788  9787.0     2020-10-29  ...           NaN                other
# 9789  9788.0     2020-10-29  ...           NaN                other
# 9790  9789.0     2020-10-29  ...           NaN                other
# 9791  9790.0     2020-10-29  ...           NaN                other
# 9792  9791.0     2020-10-29  ...           NaN                  NaN
#
# [9793 rows x 11 columns]

# %%
from google.colab import drive
drive.mount('drive')

district_data_filtered.to_csv('district_data_filtered.csv')
# !cp district_data_filtered.csv "drive/My Drive/"
# Out:
# Mounted at drive

# %%
daily_cases=sl_df.loc[:,['Confirmed','Date']]

daily_cases['Date']=pd.to_datetime(daily_cases['Date'])
daily_cases
daily_cases['Date']=daily_cases['Date'].dt.strftime('%m-%d')
daily_cases
daily_cases['Confirmed']=daily_cases['Confirmed'].diff()
daily_cases

#date
#daily['Date']=date
#daily
# Out:
#      Confirmed   Date
# 0          NaN  01-22
# 1          0.0  01-23
# 2          0.0  01-24
# 3          0.0  01-25
# 4          0.0  01-26
# ..         ...    ...
# 276      368.0  10-24
# 277      351.0  10-25
# 278      541.0  10-26
# 279      457.0  10-27
# 280      335.0  10-28
#
# [281 rows x 2 columns]

# %%
daily_cases.plot(kind='line',x='Date',y='Confirmed')

# %%
Cases_Cumulative=sl_df.loc[:,['Confirmed','Date']]
Cases_Cumulative['Date']=pd.to_datetime(Cases_Cumulative['Date'])
Cases_Cumulative['Date']=Cases_Cumulative['Date'].dt.strftime('%m-%d')
Cases_Cumulative
# Out:
#      Confirmed   Date
# 0            0  01-22
# 1            0  01-23
# 2            0  01-24
# 3            0  01-25
# 4            0  01-26
# ..         ...    ...
# 276       7521  10-24
# 277       7872  10-25
# 278       8413  10-26
# 279       8870  10-27
# 280       9205  10-28
#
# [281 rows x 2 columns]
